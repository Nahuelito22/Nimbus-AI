# %% [markdown]
# # Exploracion Api NOAA

# %% [markdown]
# ## Prueba de API y filtrado de estaciones Mendocinas

# %% [markdown]
#  Importar librerías y cargar el Token

# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv

# Cargamos las variables de entorno desde el archivo .env
load_dotenv()

# Leemos el token de forma segura
TOKEN = os.getenv('NOAA_TOKEN')

# Verificamos que el token se haya cargado correctamente
if not TOKEN:
    print("¡Error! No se encontró el token. Asegúrate de que el archivo .env está en la raíz del proyecto.")
else:
    print("Token cargado exitosamente.")

# Configuramos los datos para las futuras llamadas a la API
headers = {'token': TOKEN}
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/"
# Out:
# Token cargado exitosamente.

# %% [markdown]
# Obtencion de estaciones meteorologicas de Argentina

# %%
# El "endpoint" es la parte de la URL que le dice a la API qué queremos, en este caso, "stations"
endpoint = "stations"

# Preparamos los parámetros para la búsqueda.
# FIPS:AR es el código oficial para Argentina.
# limit=1000 nos trae hasta 1000 resultados de una vez.
params = {
    "locationid": "FIPS:AR",
    "limit": 1000  
}

print("Pidiendo la lista de estaciones a la NOAA...")
# Hacemos la llamada a la API
response = requests.get(base_url + endpoint, headers=headers, params=params)
response.raise_for_status() # Esto verificará si la llamada fue exitosa

print("¡Lista recibida! Creando DataFrame...")
# Convertimos la respuesta (que está en formato JSON) a un DataFrame de pandas
stations_df = pd.DataFrame(response.json()['results'])

# Mostramos las primeras 5 filas para ver cómo se ven los datos
stations_df.head()
# Out:
# Pidiendo la lista de estaciones a la NOAA...
# ¡Lista recibida! Creando DataFrame...
#    elevation     mindate     maxdate  latitude                       name  \
# 0      109.0  1981-01-01  2000-06-01    -29.60                BAIBENE, AR
# 1       75.0  1981-01-01  2000-06-01    -29.82               BONPLAND, AR
# 2       90.0  1981-01-01  2000-06-01    -29.98  CAZADORES CORRENTINOS, AR
# 3       71.0  1981-01-01  2000-06-01    -30.78              CHAJAR355, AR
# 4       74.0  1981-01-01  2000-06-01    -30.03       COLONIA LIBERTAD, AR
#
#    datacoverage                 id elevationUnit  longitude
# 0           1.0  GHCND:AR000000001        METERS     -58.15
# 1           1.0  GHCND:AR000000002        METERS     -57.42
# 2           1.0  GHCND:AR000000003        METERS     -58.28
# 3           1.0  GHCND:AR000000004        METERS     -58.15
# 4           1.0  GHCND:AR000000005        METERS     -57.82

# %% [markdown]
# Filtramos las estaciones mendocinas

# %%
# 1. Definimos el "cajón" geográfico aproximado para la provincia de Mendoza.
#    (Latitud: de sur a norte, Longitud: de oeste a este)
min_lat, max_lat = -37.5, -32.0
min_lon, max_lon = -70.5, -66.5

print(f"Filtrando estaciones dentro del área geográfica de Mendoza...")

# 2. Aplicamos el filtro geográfico.
#    Pedimos todas las filas donde la latitud Y la longitud estén dentro de nuestros límites.
mendoza_stations_geo = stations_df[
    (stations_df['latitude'] >= min_lat) & (stations_df['latitude'] <= max_lat) &
    (stations_df['longitude'] >= min_lon) & (stations_df['longitude'] <= max_lon)
]

# 3. Mostramos el resultado, ordenado por la fecha más reciente de datos.
print("\nEstaciones encontradas en la región de Mendoza (filtrado por coordenadas):")
print(mendoza_stations_geo[['id', 'name', 'mindate', 'maxdate']].sort_values(by='maxdate', ascending=False))
# Out:
# Filtrando estaciones dentro del área geográfica de Mendoza...
#
# Estaciones encontradas en la región de Mendoza (filtrado por coordenadas):
#                    id                      name     mindate     maxdate
# 25  GHCND:AR000087418          MENDOZA AERO, AR  1957-06-30  2025-08-24
# 58  GHCND:ARM00087416            SAN MARTIN, AR  1973-01-01  2025-08-24
# 59  GHCND:ARM00087420  MENDOZA OBSERVATORIO, AR  1973-01-01  2025-08-24
# 66  GHCND:ARM00087506              MALARGUE, AR  1967-06-01  2025-08-24
# 67  GHCND:ARM00087509            SAN RAFAEL, AR  1973-01-01  2025-08-24

# %% [markdown]
# Verificar que las estaciones estén dentro de Mendoza

# %%
import folium

# 1. Creamos un mapa base, centrado en Mendoza.
#    Coordenadas aproximadas del centro de la provincia.
mapa_verificacion = folium.Map(location=[-34.6, -68.5], zoom_start=6)

# 2. Añadimos TODAS las estaciones de Argentina al mapa en color azul.
print("Añadiendo todas las estaciones de Argentina al mapa (puntos azules)...")
for index, estacion in stations_df.iterrows():
    folium.CircleMarker(
        location=[estacion['latitude'], estacion['longitude']],
        radius=3,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"{estacion['name']}\nID: {estacion['id']}" # Etiqueta al hacer clic
    ).add_to(mapa_verificacion)

# 3. Añadimos las estaciones filtradas para Mendoza en color rojo y más grandes.
print("Resaltando las estaciones filtradas para Mendoza (puntos rojos)...")
for index, estacion in mendoza_stations_geo.iterrows():
    folium.CircleMarker(
        location=[estacion['latitude'], estacion['longitude']],
        radius=5,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=1.0,
        popup=f"FILTRADA: {estacion['name']}\nID: {estacion['id']}"
    ).add_to(mapa_verificacion)

print("\n¡Mapa generado! Mostrando el mapa a continuación...")

# 4. Mostramos el mapa en la salida de la celda.
mapa_verificacion
# Out:
# Añadiendo todas las estaciones de Argentina al mapa (puntos azules)...
# Resaltando las estaciones filtradas para Mendoza (puntos rojos)...
#
# ¡Mapa generado! Mostrando el mapa a continuación...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a36e641bca363d651e81cc4d485da35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a36e641bca363d651e81cc4d485da35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a36e641bca363d651e81cc4d485da35 = L.map(
#                 &quot;map_3a36e641bca363d651e81cc4d485da35&quot;,
#                 {
#                     center: [-34.6, -68.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94c41b9d4ee68fd7474274c912a7fe3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94c41b9d4ee68fd7474274c912a7fe3c.addTo(map_3a36e641bca363d651e81cc4d485da35);
#
#
#             var circle_marker_97452141f39ccb72c366a2aa0f87c75d = L.circleMarker(
#                 [-29.6, -58.15],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a36e641bca363d651e81cc4d485da35);
#
#
#         var popup_c2c4815aa74e91e0caa72600cada577d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6695c446d391dd1abbaff549c6f911d2 = $(`&lt;div id=&quot;html_6695c446d391dd1abbaff549c6f911d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAIBENE, AR ID: GHCND:AR000000001&lt;/div&gt;`)[0];
#                 popup_c2c4815aa74e91e0caa72600cada577d.setContent(html_6695c446d391dd1abbaff549c6f911d2);
#
#
#
#         circle_marker_97452141f39ccb72c366a2aa0f87c75d.bindPopup(popup_c2c4815aa74e91e0caa72600cada577d)
#         ;
#
#
#
#
#             var circle_marker_b4fd4791a38e867d4828e2998ff82030 = L.circleMarker(
#                 [-29.82, -57.42],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a36e641bca363d651e81cc4d485da35);
#
#
#         var popup_ef3f316daf159e9b4bee04f09a677ca0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6871a42c1538d65cfc28d79b2951fa64 = $(`&lt;div id=&quot;html_6871a42c1538d65cfc28d79b2951fa64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BONPLAND, AR ID: GHCND:AR000000002&lt;/div&gt;`)[0];
#                 popup_ef3f316daf159e9b4bee04f09a677ca0.setContent(html_6871a42c1538d65cfc28d79b2951fa64);
#
#
#
#         circle_marker_b4fd4791a38e867d4828e2998ff82030.bindPopup(popup_ef3f316daf159e9b4bee04f09a677ca0)
#         ;
#
#
#
#
#             var circle_marker_c6f41c3d2a60978230975b813c874707 = L.circleMarker(
#                 [-29.98, -58.28],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a36e641bca363d651e81cc4d485da35);
#
#
#         var popup_fc627a2aa8b3bfdf2432e639d8726646 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07cc69d54e0b89b1b337a4d39430a109 = $(`&lt;div id=&quot;html_07cc69d54e0b89b1b337a4d39430a109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAZADORES CORRENTINOS, AR ID: GHCND:AR000000003&lt;/div&gt;`)[0];
#                 popup_fc627a2aa8b3bfdf2432e639d8726646.setContent(html_07cc69d54e0b89b1b337a4d39430a109);
#
#
#
#         circle_marker_c6f41c3d2a60978230975b813c874707.bindPopup(popup_fc627a2aa8b3bfdf2432e639d8726646)
#         ;
#
#
#
#
#             var circle_marker_

# %% [markdown]
# Como podemos observar en el mapa, el box (Cajon) creado para filtrar estaciones de mendoza funciono perfectamente.

# %% [markdown]
# Consultar el Estado de la API y peticiones disponibles

# %% [markdown]
# ## Testeo de descarga de API

# %%
Primero descargamos datos de muestra para probar el funcionamiento de la Api

# %%
# --- 1. Definimos los Parámetros de nuestra consulta ---
endpoint = "data"
params = {
    "datasetid": "GHCND",                   # El dataset de resúmenes diarios.
    "stationid": "GHCND:AR000087418",        # ID de la estación MENDOZA AERO.
    "startdate": "2024-01-01",              # Fecha de inicio.
    "enddate": "2024-01-31",                # Fecha de fin (un mes de datos).
    "limit": 1000,                          # Límite de registros por página.
    "units": "metric"                       # Pedimos los datos en unidades métricas (°C, mm).
}

# --- 2. Hacemos la llamada a la API ---
print(f"Pidiendo datos para la estación {params['stationid']}...")
response = requests.get(base_url + endpoint, headers=headers, params=params)
response.raise_for_status() # Verificamos que la llamada fue exitosa.
print("¡Datos recibidos con éxito!")

# --- 3. Procesamos los datos para hacerlos legibles ---
# La API devuelve los datos en formato JSON. Lo convertimos a un DataFrame.
data = response.json().get('results', [])
df_raw = pd.DataFrame(data)

if not df_raw.empty:
    # La API entrega los datos en un formato "largo". Lo "pivotamos" para tener
    # una fila por día y una columna por cada tipo de dato (TMAX, TMIN, etc.)
    df_datos_mes = df_raw.pivot_table(
        index='date', 
        columns='datatype', 
        values='value'
    ).reset_index()

    # Convertimos la columna de fecha a un formato de fecha real.
    df_datos_mes['date'] = pd.to_datetime(df_datos_mes['date'])

    print("\n--- Muestra de Datos Meteorológicos Obtenidos (Enero 2024) ---")
    print(df_datos_mes.head())
else:
    print("\nNo se encontraron datos para el período y estación seleccionados.")
# Out:
# Pidiendo datos para la estación GHCND:AR000087418...
# ¡Datos recibidos con éxito!
#
# --- Muestra de Datos Meteorológicos Obtenidos (Enero 2024) ---
# datatype       date  PRCP  TAVG  TMAX  TMIN
# 0        2024-01-01   NaN  26.2   NaN   NaN
# 1        2024-01-02   NaN  27.4   NaN   NaN
# 2        2024-01-03  13.0  26.2  36.1  16.6
# 3        2024-01-04   0.0  28.4   NaN  22.8
# 4        2024-01-05   NaN  29.0  35.8  22.7

# %% [markdown]
# ## Descarga masiva (bulk)

# %% [markdown]
# Descarga masiva de 2000 a 2024 - Con checkpoints por estación descargada

# %%
import requests
import pandas as pd
import time
import os
from dotenv import load_dotenv
import calendar

# --- (Configuración Inicial) ---
load_dotenv()
TOKEN = os.getenv('NOAA_TOKEN')
headers = {'token': TOKEN}
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/"
print("Preparando la lista de estaciones objetivo...")
estaciones_recientes_df = mendoza_stations_geo[pd.to_datetime(mendoza_stations_geo['maxdate']).dt.year >= 2010].copy()
estaciones_objetivo = pd.Series(estaciones_recientes_df.name.values, index=estaciones_recientes_df.id).to_dict()
print(f"Se procesarán {len(estaciones_objetivo)} estaciones.")
for station_id, station_name in estaciones_objetivo.items():
    print(f"- {station_name} ({station_id})")

# --- Función de Descarga (CON LA LÓGICA DE REINTENTOS REINCORPORADA) ---
def descargar_datos_historicos(station_id, start_year, end_year):
    print(f"\nIniciando descarga para la estación: {station_id}...")
    lista_datos_anuales = []
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            ultimo_dia_mes = calendar.monthrange(year, month)[1]
            start_date = f"{year}-{str(month).zfill(2)}-01"
            end_date = f"{year}-{str(month).zfill(2)}-{ultimo_dia_mes}"
            params = {"datasetid": "GHCND", "stationid": station_id, "startdate": start_date, "enddate": end_date, "limit": 1000, "units": "metric"}
            
            # === LÓGICA DE REINTENTOS ===
            intentos = 3
            for i in range(intentos):
                try:
                    response = requests.get(base_url + "data", headers=headers, params=params)
                    peticiones_restantes = response.headers.get('X-RateLimit-Remaining', 'N/A')
                    response.raise_for_status()
                    data = response.json().get('results', [])
                    if data:
                        lista_datos_anuales.append(pd.DataFrame(data))
                        print(f"  -> Datos para {month}/{year} OK. (Peticiones restantes: {peticiones_restantes})")
                    else:
                        print(f"  -> Sin datos para {month}/{year}. (Peticiones restantes: {peticiones_restantes})")
                    break 
                except requests.exceptions.HTTPError as e:
                    if e.response.status_code == 503 and i < intentos - 1:
                        print(f"  -> ERROR 503. Reintentando en 10 seg... (Intento {i+1}/{intentos})")
                        time.sleep(10)
                    else:
                        print(f"  -> ERROR al obtener datos para {month}/{year}. Error: {e}")
                        break
                except Exception as e:
                    print(f"  -> ERROR al obtener datos para {month}/{year}. Error: {e}")
                    break
            
            time.sleep(0.5)
            
    if lista_datos_anuales:
        return pd.concat(lista_datos_anuales, ignore_index=True)
    else:
        return pd.DataFrame()

# --- Bucle Principal (con Checkpoints y Reanudación) ---
AÑO_INICIO = 2000
AÑO_FIN = 2024 

for station_id, station_name in estaciones_objetivo.items():
    nombre_archivo_checkpoint = f"../data/raw/station_{station_id.replace(':', '_')}.csv"
    if os.path.exists(nombre_archivo_checkpoint):
        print(f"\nArchivo '{nombre_archivo_checkpoint}' ya existe. Saltando estación {station_name}.")
        continue
    
    datos_estacion = descargar_datos_historicos(station_id, AÑO_INICIO, AÑO_FIN)
    
    if not datos_estacion.empty:
        datos_estacion['station_name'] = station_name
        datos_estacion.to_csv(nombre_archivo_checkpoint, index=False)
        print(f"✅ Checkpoint guardado para {station_name} en '{nombre_archivo_checkpoint}'")

print("\n--- Proceso de Descarga Completado para todas las estaciones ---")
# Out:
# Preparando la lista de estaciones objetivo...
# Se procesarán 5 estaciones.
# - MENDOZA AERO, AR (GHCND:AR000087418)
# - SAN MARTIN, AR (GHCND:ARM00087416)
# - MENDOZA OBSERVATORIO, AR (GHCND:ARM00087420)
# - MALARGUE, AR (GHCND:ARM00087506)
# - SAN RAFAEL, AR (GHCND:ARM00087509)
#
# Archivo '../data/raw/station_GHCND_AR000087418.csv' ya existe. Saltando estación MENDOZA AERO, AR.
#
# Iniciando descarga para la estación: GHCND:ARM00087416...
#   -> Datos para 1/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2007 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 9/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2024 OK. (Peticiones restantes: N/A)
# ✅ Checkpoint guardado para SAN MARTIN, AR en '../data/raw/station_GHCND_ARM00087416.csv'
#
# Iniciando descarga para la estación: GHCND:ARM00087420...
#   -> Sin datos para 1/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2000. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2001. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2002. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2003. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2004. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Sin datos para 5/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2004. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2005. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2006. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Sin datos para 11/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2006. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2007. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Sin datos para 5/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2009. (Peticiones restantes: N/A)
#   -> Datos para 6/2009 OK. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2010. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2011. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2012. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2013. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2014. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2015. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2016. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2017. (Peticiones restantes: N/A)
#   -> Datos para 3/2017 OK. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2017. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2018. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 6/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2019. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2019. (Peticiones restantes: N/A)
#   -> Datos para 12/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2023 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 4/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2024 OK. (Peticiones restantes: N/A)
# ✅ Checkpoint guardado para MENDOZA OBSERVATORIO, AR en '../data/raw/station_GHCND_ARM00087420.csv'
#
# Iniciando descarga para la estación: GHCND:ARM00087506...
#   -> Datos para 1/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2000 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 7/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2000 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2007 OK. (Peticiones restantes: N/A)
#   -> Sin datos para 7/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 8/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 9/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 10/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 11/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 12/2007. (Peticiones restantes: N/A)
#   -> Sin datos para 1/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2008. (Peticiones restantes: N/A)
#   -> Sin datos para 5/2008. (Peticiones restantes: N/A)
#   -> Datos para 6/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2009 OK. (Peticiones restantes: N/A)
#   -> Sin datos para 2/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 3/2009. (Peticiones restantes: N/A)
#   -> Sin datos para 4/2009. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Sin datos para 5/2009. (Peticiones restantes: N/A)
#   -> Datos para 6/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2011 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 2/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2018 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 3/2018 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 4/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2018 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 9/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2018 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 1/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2019 OK. (Peticiones restantes: N/A)
# ...
#   -> Datos para 5/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2001 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2002 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2003 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2004 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2005 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2006 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2007 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2008 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2009 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2010 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2011 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2012 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2013 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2014 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2015 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2016 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2017 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2018 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2019 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2020 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2021 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 8/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2021 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2022 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 6/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2023 OK. (Peticiones restantes: N/A)
#   -> Datos para 1/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 2/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 3/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 4/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 5/2024 OK. (Peticiones restantes: N/A)
#   -> ERROR 503. Reintentando en 10 seg... (Intento 1/3)
#   -> Datos para 6/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 7/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 8/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 9/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 10/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 11/2024 OK. (Peticiones restantes: N/A)
#   -> Datos para 12/2024 OK. (Peticiones restantes: N/A)
# ✅ Checkpoint guardado para SAN RAFAEL, AR en '../data/raw/station_GHCND_ARM00087509.csv'
#
# --- Proceso de Descarga Completado para todas las estaciones ---
